# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=93bbb8455526a703d37e8fc24b2cb36443e40c589b4ee07f7978fee1a4df11ed
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...

# %%
#practical no.4
from googletrans import Translator

from googletrans import Translator

def german_english(german_text):
    translator = Translator()
    translation = translator.translate(german_text, src='de', dest='en')
    return translation.text

german_text = "guten tag"
english_translation = german_english(german_text)
print(f"German: {german_text}")
print(f"English: {english_translation}")
# Out:
# German: guten tag
# English: Good day
